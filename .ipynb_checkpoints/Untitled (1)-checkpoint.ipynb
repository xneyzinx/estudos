# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:\\Users\\Nei\\Desktop\\UFPI\\Data Science\\Biblioteca San Francisco\\Library_Usage.csv")

df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR               28              13
# 1                 0                  ADULT               21              10
# 2                 0                  ADULT              275             559
# 3                 0                  ADULT               73              38
# 4                 0                  ADULT              182              90
#
#         Age Range Home Library Code Home Library Definition  \
# 0  65 to 74 years                 X            Main Library
# 1  55 to 59 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  45 to 54 years                M8             Mission Bay
# 4  45 to 54 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# 0                 November                    2012                      z
# 1                  October                    2015                      z
# 2                  January                    2015                      z
# 3                 February                    2016                      z
# 4                     July                    2016                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        email                    True
# 1                        email                    True
# 2                        email                    True
# 3                        email                    True
# 4                        email                    True
#
#    Year Patron Registered  Outside of County  Supervisor District
# 0                    2003               True                  NaN
# 1                    2003              False                  NaN
# 2                    2003               True                  NaN
# 3                    2003              False                  NaN
# 4                    2003              False                  NaN

# %%
df = df.iloc[: , [1,2,3,4,6,7,8,10,11,12,13,14]]
df.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals       Age Range  \
# 0                 SENIOR               28              13  65 to 74 years
# 1                  ADULT               21              10  55 to 59 years
# 2                  ADULT              275             559  60 to 64 years
# 3                  ADULT               73              38  45 to 54 years
# 4                  ADULT              182              90  45 to 54 years
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0            Main Library                 November                    2012
# 1            Main Library                  October                    2015
# 2            Main Library                  January                    2015
# 3             Mission Bay                 February                    2016
# 4            Main Library                     July                    2016
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        email                    True
# 1                        email                    True
# 2                        email                    True
# 3                        email                    True
# 4                        email                    True
#
#    Year Patron Registered  Outside of County  Supervisor District
# 0                    2003               True                  NaN
# 1                    2003              False                  NaN
# 2                    2003               True                  NaN
# 3                    2003              False                  NaN
# 4                    2003              False                  NaN

# %%
df.columns = ["patron_type", "total_checkouts", "total_renewals", "age_range", "home_library", "active_month",
             "active_year", "notice_preference", "provided_email", "year_patron_registered", "outside_county",
             "supervisor_district"]


df["year_patron_registered"].value_counts()
# Out:
# 2003    69257
# 2015    53951
# 2014    51902
# 2013    48251
# 2012    37395
# 2011    26531
# 2016    26288
# 2010    24321
# 2009    22307
# 2008    20518
# 2007    13289
# 2006    10776
# 2005     9668
# 2004     8994
# Name: year_patron_registered, dtype: int64

# %%
def convert_years(year):
    if year == "None":
        return year
    else:
        return int(year)

df["active_year"] = df["active_year"].apply(convert_years)

# %%
patron_registration = df["year_patron_registered"].value_counts().sort_index().drop(2003)
patron_registration.iloc[:]
# Out:
# 2004     8994
# 2005     9668
# 2006    10776
# 2007    13289
# 2008    20518
# 2009    22307
# 2010    24321
# 2011    26531
# 2012    37395
# 2013    48251
# 2014    51902
# 2015    53951
# 2016    26288
# Name: year_patron_registered, dtype: int64

# %%
fig, ax = plt.subplots(1,1, figsize=(16, 8))
fig.subplots_adjust(hspace=0.4)

plot_1 = patron_registration.plot(marker="o", xticks=range(2004, 2017), xlim=[2003.5, 2016.5])
plot_1.set_title("Growth of Library Users", fontweight="bold")
plot_1.set(xlabel="Year", ylabel="Number of People that registered")
plt.grid()
plt.show()

# %%
total_checkouts = df["total_checkouts"].value_counts().sort_index()
total_checkouts.iloc[:]
# Out:
# 0        73578
# 1        23482
# 2        15924
# 3        12926
# 4        10697
# 5         9326
# 6         8076
# 7         7125
# 8         6522
# 9         5817
# 10        5344
# 11        4805
# 12        4529
# 13        4231
# 14        4198
# 15        3757
# 16        3532
# 17        3385
# 18        3142
# 19        3077
# 20        2869
# 21        2769
# 22        2574
# 23        2612
# 24        2465
# 25        2307
# 26        2334
# 27        2234
# 28        2136
# 29        1999
#          ...
# 10371        1
# 10521        1
# 10637        1
# 10809        1
# 10863        1
# 10906        1
# 11086        1
# 11102        1
# 11147        1
# 11366        1
# 11748        1
# 11817        1
# 11871        1
# 11896        1
# 12733        1
# 12740        1
# 12757        1
# 12950        1
# 13362        1
# 13784        1
# 14502        1
# 15505        1
# 15598        1
# 16060        1
# 17308        1
# 18064        1
# 18397        1
# 24093        1
# 25223        1
# 35907        1
# Name: total_checkouts, Length: 4274, dtype: int64

# %%
fig, ax = plt.subplots(1,1, figsize=(16, 8))
fig.subplots_adjust(hspace=0.4)

plot_1 = total_checkouts.plot(marker="o", xticks=range(0, 1999), xlim=[-0.5, 1999])
plot_1.set_title("Growth of checkouts", fontweight="bold")
plot_1.set(xlabel="Number of people", ylabel="Number of checkouts")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5930e3074d44> in <module>()
# ----> 1 fig, ax = plt.subplots(1,1, figsize=(16, 8))
#       2 fig.subplots_adjust(hspace=0.4)
#       3
#       4 plot_1 = total_checkouts.plot(marker="o", xticks=range(0, 1999), xlim=[-0.5, 1999])
#       5 plot_1.set_title("Growth of checkouts", fontweight="bold")
#
# NameError: name 'plt' is not defined
