# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:\\Users\\ney.dantas\\Desktop\\Cursos\\DataAnalyse\\Incomy\\adult.csv")
pd.set_option('display.max_columns', None) # To display all columns

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['age'].hist(bins=10)

# %%
df['education.num'].hist()

# %%
df['hours.per.week'].hist()

# %%
df['fnlwgt'].hist()

# %%
df['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
df2 = df[df['income']==">50K"].groupby('education')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('education')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('workclass')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('workclass')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('education.num')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('education.num')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('marital.status')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('marital.status')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('relationship')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('relationship')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('race')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('race')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('sex')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('sex')['income'].count()


d = pd.concat([df2, df3], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"].groupby('hours.per.week')['income'].count()
df3 = df[df['income']=="<=50K"].groupby('hours.per.week')['income'].count()


d = pd.concat([df2.nlargest(10), df3.nlargest(10)], axis=1)
d.plot(kind='bar', stacked=True, figsize=(16,12), fontsize=20, grid=True).legend(np.fliplr([df['income'].unique()])[0])

# %%
df2 = df[df['income']==">50K"]
df3 = df[df['income']=="<=50K"]

plt.figure(figsize=(16,8))
plt.hist(df2.age, bins=20, alpha=0.5, label='>50k')
plt.hist(df3.age, bins=20, alpha=0.5, label='<=50k')
# Out:
# (array([2408., 3101., 2264., 2822., 2625., 1746., 2103., 1831., 1117.,
#         1255.,  990.,  677.,  721.,  457.,  213.,  189.,   96.,   49.,
#           17.,   39.]),
#  array([17.  , 20.65, 24.3 , 27.95, 31.6 , 35.25, 38.9 , 42.55, 46.2 ,
#         49.85, 53.5 , 57.15, 60.8 , 64.45, 68.1 , 71.75, 75.4 , 79.05,
#         82.7 , 86.35, 90.  ]),
#  <a list of 20 Patch objects>)

# %%
pd.set_option('display.max_columns', None) # To display all columns

DF = df

categorial_cols = ['education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'income']

for cc in categorial_cols:
    dummies = pd.get_dummies(df[cc], drop_first=False)
    dummies = dummies.add_prefix("{}#".format(cc))
    df.drop(cc, axis=1, inplace=True)
    df = df.join(dummies)

# %%
from sklearn.cross_validation import train_test_split
df=df.reset_index()
train_data, test_data = train_test_split(df, train_size = 0.8, random_state = 10)
# Out:
# C:\Users\ney.dantas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error # Mean squared error regression loss

# A function that take one input of the dataset and return the RMSE (of the test data), and the intercept and coefficient
def simple_linear_model(train, test, input_feature):
    regr = linear_model.LinearRegression() # Create a linear regression object
    regr.fit(train.as_matrix(columns = [input_feature]), train.as_matrix(columns = ['income#>50K'])) # Train the model
    RMSE = mean_squared_error(test.as_matrix(columns = ['income#>50K']), 
                              regr.predict(test.as_matrix(columns = [input_feature])))**0.5 # Calculate the RMSE on test data
    return RMSE, regr.intercept_[0], regr.coef_[0][0]

# %%
input_list = df.columns.values.tolist() # list of column name
input_list.remove('income#<=50K')
input_list.remove('income#>50K')
input_list.remove('workclass')
input_list.remove('native.country')
simple_linear_result = pd.DataFrame(columns = ['feature', 'RMSE', 'intercept', 'coefficient'])

# loop that calculate the RMSE of the test data for each input 
for p in input_list:
    RMSE, w1, w0 = simple_linear_model(train_data, test_data, p)
    simple_linear_result = simple_linear_result.append({'feature':p, 'RMSE':RMSE, 'intercept':w0, 'coefficient': w1}
                                                       ,ignore_index=True)
simple_linear_result.sort_values('RMSE').head(10) # display the 10 best estimators
# Out:
#                               feature      RMSE  intercept  coefficient
# 25  marital.status#Married-civ-spouse  0.384309   0.382684     0.064700
# 45               relationship#Husband  0.392018   0.349497     0.099180
# 3                       education.num  0.400996   0.055131    -0.315327
# 27       marital.status#Never-married  0.405821  -0.290820     0.335805
# 1                                 age  0.415922   0.007351    -0.042940
# 48             relationship#Own-child  0.416257  -0.269251     0.282591
# 6                      hours.per.week  0.416447   0.007919    -0.080027
# 4                        capital.gain  0.417397   0.000013     0.226721
# 57                           sex#Male  0.417596   0.196101     0.109618
# 56                         sex#Female  0.417596  -0.196101     0.305718

# %%
RMSE, w0, w1 = simple_linear_model(train_data, test_data, 'capital.loss')
print ('RMSE for sqm_living is: %s ' %RMSE)
print ('intercept is: %s' %w0)
print ('coefficient is: %s' %w1)
# Out:
# RMSE for sqm_living is: 0.4220555318772031
# intercept is: 0.22714736016186343
# coefficient is: 0.00015706929876960682

# %%
DF.head()
# Out:
#    age workclass  fnlwgt  education.num marital.status         occupation  \
# 0   90         ?   77053              9        Widowed                  ?
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66         ?  186061             10        Widowed                  ?
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native.country income
# 0  United-States  <=50K
# ...

# %%
DF.fillna(np.nan)
# Out:
#        age         workclass  fnlwgt  education.num      marital.status  \
# 0       90                 ?   77053              9             Widowed
# 1       82           Private  132870              9             Widowed
# 2       66                 ?  186061             10             Widowed
# 3       54           Private  140359              4            Divorced
# 4       41           Private  264663             10           Separated
# 5       34           Private  216864              9            Divorced
# 6       38           Private  150601              6           Separated
# 7       74         State-gov   88638             16       Never-married
# 8       68       Federal-gov  422013              9            Divorced
# 9       41           Private   70037             10       Never-married
# 10      45           Private  172274             16            Divorced
# 11      38  Self-emp-not-inc  164526             15       Never-married
# ...

# %%
DF['income']=DF['income'].map({'<=50K': 0, '>50K': 1})
DF.head()
# Out:
#    age workclass  fnlwgt  education.num marital.status         occupation  \
# 0   90         ?   77053              9        Widowed                  ?
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66         ?  186061             10        Widowed                  ?
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native.country  income
# 0  United-States       0
# ...

# %%
numeric_features = ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
# Correlation matrix between numerical values
g = sns.heatmap(DF[numeric_features].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
# Explore Education Num vs Income
g = sns.factorplot(x="education.num",y="income",data=DF,kind="bar",size = 6,palette = "muted")
g.despine(left=True)
g = g.set_ylabels(">50K probability")

# %%
# Explore Age vs Income
g = sns.FacetGrid(DF, col='income')
g = g.map(sns.distplot, "age")

# %%
DF.head()
# Out:
#    age workclass  fnlwgt  education.num marital.status         occupation  \
# 0   90         ?   77053              9        Widowed                  ?
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66         ?  186061             10        Widowed                  ?
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native.country  income
# 0  United-States       0
# ...

# %%
DF[DF['income']==0].age.hist(bins=30)
DF[DF['income']==1].age.hist(bins=30)

# %%
DF[ (DF['age']>50) & (DF['age']<55)] ['income'].value_counts()
# Out:
# 0    1156
# 1     796
# Name: income, dtype: int64

# %%
a = DF[DF['age']>49]
a = a[a['age']<53]
a['income'].value_counts()
# Out:
# 0    980
# 1    695
# Name: income, dtype: int64

# %%
pd.set_option('display.max_rows', 1000)

a = DF.sort_values('age').groupby(['age'])['occupation'].value_counts()

a = pd.DataFrame(data=a)
a
# Out:
#                        occupation
# age occupation
# 17  Other-service             129
#     Sales                      87
#     ?                          65
#     Handlers-cleaners          40
#     Adm-clerical               23
#     Craft-repair               14
#     Prof-specialty             10
#     Farming-fishing             9
#     Priv-house-serv             8
#     Protective-serv             3
#     Transport-moving            3
#     Machine-op-inspct           2
#     Exec-managerial             1
#     Tech-support                1
# 18  Other-service             152
#     Sales                     115
#     ?                          95
#     Adm-clerical               55
#     Handlers-cleaners          50
#     Craft-repair               17
#     Machine-op-inspct          17
#     Farming-fishing            14
#     Prof-specialty             10
#     Transport-moving            8
#     Exec-managerial             6
#     Protective-serv             5
# ...

# %%
a = DF.sort_values('age').groupby(['age'])['income'].value_counts()

a = pd.DataFrame(data=a)

a.unstack('income')
#pd.pivot_table(a, index=['age'], columns=['income'])
# Out:
#        income
# income      0      1
# age
# 17      395.0    NaN
# 18      550.0    NaN
# 19      710.0    2.0
# 20      753.0    NaN
# 21      717.0    3.0
# 22      752.0   13.0
# 23      865.0   12.0
# 24      767.0   31.0
# 25      788.0   53.0
# 26      722.0   63.0
# 27      754.0   81.0
# 28      748.0  119.0
# 29      679.0  134.0
# 30      690.0  171.0
# 31      705.0  183.0
# 32      639.0  189.0
# 33      684.0  191.0
# 34      643.0  243.0
# 35      659.0  217.0
# 36      635.0  263.0
# 37      566.0  292.0
# 38      545.0  282.0
# 39      538.0  278.0
# 40      526.0  268.0
# 41      529.0  279.0
# 42      510.0  270.0
# 43      497.0  273.0
# 44      443.0  281.0
# 45      446.0  288.0
# 46      445.0  292.0
# 47      420.0  288.0
# 48      326.0  217.0
# 49      371.0  206.0
# 50      341.0  261.0
# 51      353.0  242.0
# 52      286.0  192.0
# 53      275.0  189.0
# 54      242.0  173.0
# 55      273.0  146.0
# 56      248.0  118.0
# 57      227.0  131.0
# ...

# %%
pd.pivot_table(DF, 'income', 'age', ['occupation','sex']) #1=df 2=valor a ser avaliado 3=indice, 4=colunas
# Out:
# occupation         ?           Adm-clerical           Armed-Forces  \
# sex           Female      Male       Female      Male         Male
# age
# 17          0.000000  0.000000     0.000000  0.000000          NaN
# 18          0.000000  0.000000     0.000000  0.000000          NaN
# 19          0.017241  0.000000     0.000000  0.000000          NaN
# 20          0.000000  0.000000     0.000000  0.000000          NaN
# 21          0.000000  0.000000     0.011905  0.000000          NaN
# 22          0.000000  0.000000     0.000000  0.000000          NaN
# 23          0.000000  0.000000     0.000000  0.042553          0.0
# 24          0.000000  0.058824     0.000000  0.058824          0.0
# 25          0.000000  0.000000     0.065934  0.081081          NaN
# 26          0.062500  0.000000     0.064103  0.093023          NaN
# 27          0.250000  0.000000     0.037975  0.030303          NaN
# 28          0.035714  0.000000     0.044776  0.166667          NaN
# ...

# %%
DF.groupby('occupation')['income'].value_counts().unstack('income')
# Out:
# income                0     1
# occupation
# ?                  1652   191
# Adm-clerical       3263   507
# Armed-Forces          8     1
# Craft-repair       3170   929
# Exec-managerial    2098  1968
# Farming-fishing     879   115
# Handlers-cleaners  1284    86
# Machine-op-inspct  1752   250
# Other-service      3158   137
# Priv-house-serv     148     1
# Prof-specialty     2281  1859
# Protective-serv     438   211
# Sales              2667   983
# Tech-support        645   283
# Transport-moving   1277   320

# %%
DF
# Out:
#        age         workclass  fnlwgt  education.num         marital.status  \
# 0       90                 ?   77053              9                Widowed
# 1       82           Private  132870              9                Widowed
# 2       66                 ?  186061             10                Widowed
# 3       54           Private  140359              4               Divorced
# 4       41           Private  264663             10              Separated
# 5       34           Private  216864              9               Divorced
# 6       38           Private  150601              6              Separated
# 7       74         State-gov   88638             16          Never-married
# 8       68       Federal-gov  422013              9               Divorced
# 9       41           Private   70037             10          Never-married
# 10      45           Private  172274             16               Divorced
# ...
