# %%
import pandas as pd
import numpy as np

my_cols = ["mat", "nome", "prova", "nota", "res_cota", "res_def"]

df = pd.read_csv("C:\\Users\\ney.dantas\\Desktop\\cfm_excel.csv", encoding = "ISO-8859-1", header=None, names=my_cols)

df.sort_values("prova", ascending=False)
# Out:
#                                                    mat nome  prova  nota  \
# 193104356                       TIAGO FONSECA MEDEIROS    A     45   Não
# 193109408                    DIOGO FRANKLIN DEOLIVEIRA    D     44   Não
# 193104662                   LUCIO FELIPPE DE MELLONETO    B     43   Não
# 193103251              WELINGTON YORIHIKO LIMA AKAMINE    D     43   Não
# 193122430                        FELIPE FREITAS SOARES    C     43   Sim
# 193110612              MATHEUSDE BESSA PERDIGAO FREIRE    D     42   Não
# 193116444        ALESSANDRA GUARACY DEOLIVEIRA SANCHES    B     42   Não
# 193105498                      MAURILIO COSTA DA SILVA    B     40   Sim
# 193106301     JOAO FRANCISCO GONCALVES SOBRINHO JUNIOR    D     40   Sim
# 193107229               NEY MOURA FE LEOPOLDINO DANTAS    A     40   Não
# 193111747             PEDROHENRIQUE POTIGUARA CARVALHO    A     40   Não
# 193108068                     ALISSON TAVARES DE SOUZA    A     40   Sim
# ...
